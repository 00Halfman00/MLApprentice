# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/oscarsanchez/PYTHON/MLApprentice/pythonA-Z'

# %%
pwd
# Out:
# '/Users/oscarsanchez/PYTHON/MLApprentice/pythonA-Z'

# %%
df = pd.read_csv('/Users/oscarsanchez/PYTHON/MLApprentice/pythonA-Z/S6-Movie-Ratings.csv')

# %%
df.shape
# Out:
# (559, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
#fix column heading to keep CamelCase
cap_columns = []
for column in df.columns:
  parts = column.split(' ')
  cap_parts = [part.capitalize() for part in parts]
  cleaned = ''.join(cap_parts)
  cap_columns.append(cleaned)
df.columns = cap_columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Film                    559 non-null    object
#  1   Genre                   559 non-null    object
#  2   RottenTomatoesRatings%  559 non-null    int64
#  3   AudienceRatings%        559 non-null    int64
#  4   Budget(million$)        559 non-null    int64
#  5   YearOfRelease           559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.head()
# Out:
#                     Film      Genre  RottenTomatoesRatings%  AudienceRatings%  \
# 0  (500) Days of Summer      Comedy                      87                81
# 1            10,000 B.C.  Adventure                       9                44
# 2             12 Rounds      Action                      30                52
# 3              127 Hours  Adventure                      93                84
# 4              17 Again      Comedy                      55                70
#
#    Budget(million$)  YearOfRelease
# 0                 8           2009
# 1               105           2008
# 2                20           2009
# 3                18           2010
# 4                20           2009

# %%
df['YearOfRelease'] = df['YearOfRelease'].astype('category')
df['Film'] = df['Film'].astype('category')
df['Genre'] = df['Genre'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Film                    559 non-null    category
#  1   Genre                   559 non-null    category
#  2   RottenTomatoesRatings%  559 non-null    int64
#  3   AudienceRatings%        559 non-null    int64
#  4   Budget(million$)        559 non-null    int64
#  5   YearOfRelease           559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
df.head()
# Out:
#                     Film      Genre  RottenTomatoesRatings%  AudienceRatings%  \
# 0  (500) Days of Summer      Comedy                      87                81
# 1            10,000 B.C.  Adventure                       9                44
# 2             12 Rounds      Action                      30                52
# 3              127 Hours  Adventure                      93                84
# 4              17 Again      Comedy                      55                70
#
#    Budget(million$) YearOfRelease
# 0                 8          2009
# 1               105          2008
# 2                20          2009
# 3                18          2010
# 4                20          2009

# %%
type(df['YearOfRelease'][0])
# Out:
# numpy.int64

# %%
df.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
df.describe()
# Out:
#        RottenTomatoesRatings%  AudienceRatings%  Budget(million$)
# count              559.000000        559.000000        559.000000
# mean                47.309481         58.744186         50.236136
# std                 26.413091         16.826887         48.731817
# min                  0.000000          0.000000          0.000000
# 25%                 25.000000         47.000000         20.000000
# 50%                 46.000000         58.000000         35.000000
# 75%                 70.000000         72.000000         65.000000
# max                 97.000000         96.000000        300.000000

# %%
import matplotlib. pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = 12, 7

# %% [markdown]
# Joinplots

# %%
j1 = sns.jointplot(data=df, x='RottenTomatoesRatings%',  hue='Genre', y='AudienceRatings%', height=7)

# %%
j2 = sns.jointplot(data=df, x='RottenTomatoesRatings%', y='AudienceRatings%', height=7, kind='hex' )

# %%
j3 = sns.jointplot(data=df, x='RottenTomatoesRatings%', y='Budget(million$)', height=7, kind='hex' )

# %% [markdown]
# Histograms

# %%
v2 = sns.displot(df['AudienceRatings%'], height=7, kind='hist' )

# %%
v3 = sns.displot(df['RottenTomatoesRatings%'], height=7, kind='hist', color='purple' )

# %%
plt.hist(df['AudienceRatings%'], bins=15)
plt.show()

# %%
plt.hist(df['RottenTomatoesRatings%'], bins=15)
plt.show()

# %% [markdown]
# Stacked Histograms

# %%
plt.hist(df[df.Genre == 'Action']['Budget(million$)'])
plt.hist(df[df.Genre == 'Drama']['Budget(million$)'])
plt.hist(df[df.Genre == 'Comedy']['Budget(million$)'])
plt.hist(df[df.Genre == 'Advebture']['Budget(million$)'])
plt.show()

# %%
plt.hist([ df[df.Genre == 'Action']['Budget(million$)'], \
  df[df.Genre == 'Drama']['Budget(million$)']], \
  stacked=True)
# Out:
# (array([[29., 43., 24., 14., 13., 14., 11.,  3.,  2.,  1.],
#         [94., 69., 32., 15., 13., 15., 11.,  3.,  2.,  1.]]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <a list of 2 BarContainer objects>)

# %%
def categories(data, col):
  results = []
  for genre in data[col].cat.categories:
    results.append(df[df[col] == genre]['Budget(million$)'])
  return results

# %%
plt.hist(categories(df, 'Genre'), stacked=True, label=df['Genre'].cat.categories )
plt.legend()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Film                    559 non-null    category
#  1   Genre                   559 non-null    category
#  2   RottenTomatoesRatings%  559 non-null    int64
#  3   AudienceRatings%        559 non-null    int64
#  4   Budget(million$)        559 non-null    int64
#  5   YearOfRelease           559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
plt.hist(categories(df, 'YearOfRelease'), stacked=True, label=df['YearOfRelease'].cat.categories )
plt.legend()
plt.show()

# %%
sns.lmplot(data=df, x='RottenTomatoesRatings%',  hue='Genre', y='AudienceRatings%', height=7, aspect=1)

# %%
sns.kdeplot(df['RottenTomatoesRatings%'], df['AudienceRatings%'], shade=True, color='Purple')
plt.show()

# %%
sns.kdeplot(df['RottenTomatoesRatings%'], df['AudienceRatings%'], color='Purple')
plt.show()

# %%
sns.kdeplot(df['RottenTomatoesRatings%'], df['AudienceRatings%'], shade=True, color='Purple')
sns.kdeplot(df['RottenTomatoesRatings%'], df['AudienceRatings%'], color='Purple')
plt.show()

# %%
sns.kdeplot(df['Budget(million$)'], df['AudienceRatings%'], shade=True, color='Purple')
sns.kdeplot(df['Budget(million$)'], df['AudienceRatings%'], color='Purple' )
# Out:
# <AxesSubplot:xlabel='Budget(million$)', ylabel='AudienceRatings%'>

# %% [markdown]
# Subplots

# %%
sns.kdeplot(df['Budget(million$)'], df['RottenTomatoesRatings%'], shade=True, color='Purple')
sns.kdeplot(df['Budget(million$)'], df['RottenTomatoesRatings%'], color='Purple' )
# Out:
# <AxesSubplot:xlabel='Budget(million$)', ylabel='RottenTomatoesRatings%'>

# %%
f, ax = plt.subplots(1,2, sharex=True)
k1 = sns.kdeplot(df['Budget(million$)'], df['AudienceRatings%'], shade=True, color='Purple', ax=ax[0])
k2 = sns.kdeplot(df['Budget(million$)'], df['RottenTomatoesRatings%'], shade=True, color='Purple', ax=ax[1])
k1.set_xlim(-50, 250)
# Out:
# (-50.0, 250.0)

# %% [markdown]
# ViolinPlots

# %%
vio1 = sns.violinplot(data=df, x='Genre', y='RottenTomatoesRatings%')

# %%
box1 = sns.boxplot(data=df, x='Genre', y='RottenTomatoesRatings%')

# %%
vio2 = sns.violinplot(data=df[df.Genre == 'Drama'], x='YearOfRelease', y='RottenTomatoesRatings%')

# %%
box2 = sns.boxplot(data=df[df.Genre == 'Drama'], x='YearOfRelease', y='RottenTomatoesRatings%')

# %% [markdown]
# FacetGrids

# %%
fg = sns.FacetGrid(df, row='Genre', col='YearOfRelease', hue='Genre', height=4)
kws = dict(s=50, edgecolor='black', linewidth=0.5)
fg = fg.map(plt.scatter, 'RottenTomatoesRatings%', 'AudienceRatings%', **kws)

# %%
fg2 = sns.FacetGrid(df, row='Genre', col='YearOfRelease', hue='Genre', height=4)
fg2 = fg.map(plt.hist, 'Budget(million$)')

# %% [markdown]
# Controlling Axes and Adding Diagonals

# %%
fg = sns.FacetGrid(df, row='Genre', col='YearOfRelease', hue='Genre', height=4)
kws = dict(s=50, edgecolor='black', linewidth=0.5)
fg = fg.map(plt.scatter, 'RottenTomatoesRatings%', 'AudienceRatings%', **kws)
fg.set(xlim=(0,100), ylim=(0,100))
fg.figure.subplots_adjust(hspace=0.2, wspace=0.2)
plt.show()

# %%
fg = sns.FacetGrid(df, row='Genre', col='YearOfRelease', hue='Genre', height=4)
kws = dict(s=50, edgecolor='black', linewidth=0.5)
fg = fg.map(plt.scatter, 'RottenTomatoesRatings%', 'AudienceRatings%', **kws)
fg.set(xlim=(0,100), ylim=(0,100))
fg.figure.subplots_adjust(hspace=0.2, wspace=0.2)
for ax in fg.axes.flat:
  ax.plot((0, 100), (0, 100), c='black', ls='--')
fg.add_legend()
plt.show()
